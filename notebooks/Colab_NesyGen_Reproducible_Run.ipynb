# %% [markdown]
# # Nesy-Gen Reproducible Run
#
# Set `RUN_DATASET` to `mimic_cxr` or `iuxray`, mount Drive if desired, then run the smoke demo before launching full experiments.

# %%
# !pip install -q kagglehub
# After pushing to GitHub, replace this URL with your repository.
# !git clone https://github.com/<org-or-user>/nesy-gen.git
# %cd nesy-gen
# !pip install -q -e .[colab,eval]

# %%
RUN_DATASET = "mimic_cxr"  # or "iuxray"

from nesy_gen.data.kaggle import resolve_kaggle_dataset, print_dataset_paths

paths = resolve_kaggle_dataset(RUN_DATASET)
print_dataset_paths(paths)
DATA_ROOT = str(paths.data_root)
OUTPUT_DIR = str(paths.output_dir)

# %%
# !python scripts/run_demo.py

# %%
# PrimeKG download for full runs
# !python scripts/download_primekg.py --out data/primekg/kg.csv
